# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
X = np.random.randn(300, 2)
X[:,0] += np.arange(300)/10
X[:,1] += 10*np.sin(np.arange(300)/100)

X2 = 3*np.random.randn(100, 2)
X2[:,0] += 15

# %%
plt.scatter(X[:,0], X[:,1])
plt.scatter(X2[:,0], X2[:,1])
plt.scatter([0,10,20,30],[0,9,9,0],c='r')
plt.scatter([15],[0],c='b')

# %%
plt.scatter(X[:,0], X[:,1])
plt.scatter(X2[:,0], X2[:,1])
